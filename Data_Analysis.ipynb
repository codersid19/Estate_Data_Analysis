# %%
import pandas as pd
# Loading the Data
data = pd.read_csv("data/real_estate_data.csv")

# %% [markdown]
# Introductory Exploration

# %%
data.head()
# Out:
#    construction_year  fully_equipped_kitchen  furnished  garden  garden_area  \
# 0             1901.0                       1        0.0       0          0.0
# 1             1992.0                       1        0.0       1        430.0
# 2             1853.0                       1        0.0       1       1400.0
# 3             1918.0                       1        0.0       1       2333.0
# 4             1977.0                       1        0.0       1        500.0
#
#    house_area  locality  number_of_facades  number_of_rooms  open_fire  ...  \
# 0       203.0      1050                2.0              6.0          0  ...
# 1       250.0      1880                4.0              6.0          0  ...
# 2       475.0      4900                4.0             11.0          0  ...
# 3       325.0      7912                4.0              4.0          0  ...
# 4       400.0      6032                3.0              5.0          0  ...
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 104154 entries, 0 to 104153
# Data columns (total 21 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   construction_year            61416 non-null   float64
#  1   fully_equipped_kitchen       104154 non-null  int64
#  2   furnished                    104154 non-null  float64
#  3   garden                       104154 non-null  int64
#  4   garden_area                  104154 non-null  float64
#  5   house_area                   86890 non-null   float64
#  6   locality                     104154 non-null  int64
#  7   number_of_facades            76854 non-null   float64
#  8   number_of_rooms              104150 non-null  float64
#  9   open_fire                    104154 non-null  int64
#  10  price                        104014 non-null  float64
#  11  state_of_the_building        76982 non-null   object
# ...

# %%
data.describe()
# Out:
#        construction_year  fully_equipped_kitchen  furnished         garden  \
# count       61416.000000           104154.000000   104154.0  104154.000000
# mean         1984.107334                0.652284        0.0       0.289859
# std            37.314929                0.476248        0.0       0.453699
# min          1755.000000                0.000000        0.0       0.000000
# 25%          1964.000000                0.000000        0.0       0.000000
# 50%          1992.000000                1.000000        0.0       0.000000
# 75%          2018.000000                1.000000        0.0       1.000000
# max          2048.000000                1.000000        0.0       1.000000
#
#          garden_area    house_area       locality  number_of_facades  \
# count  104154.000000  86890.000000  104154.000000       76854.000000
# mean      115.586132    153.720888    5406.222728           2.766024
# std      1756.665631    183.354170    2958.576765           0.859290
# ...

# %%
data.columns
# Out:
# Index(['construction_year', 'fully_equipped_kitchen', 'furnished', 'garden',
#        'garden_area', 'house_area', 'locality', 'number_of_facades',
#        'number_of_rooms', 'open_fire', 'price', 'state_of_the_building',
#        'subtype_of_property', 'surface_of_the_land',
#        'surface_of_the_plot_of_land', 'swimming_pool', 'terrace',
#        'terrace_area', 'type_of_property', 'type_of_sale', 'price_per_sqft'],
#       dtype='object')

# %%
data.shape
# Out:
# (104154, 21)

# %%
data = data.drop(columns=['surface_of_the_plot_of_land'])
data.head()
# Out:
#    construction_year  fully_equipped_kitchen  furnished  garden  garden_area  \
# 0             1901.0                       1        0.0       0          0.0
# 1             1992.0                       1        0.0       1        430.0
# 2             1853.0                       1        0.0       1       1400.0
# 3             1918.0                       1        0.0       1       2333.0
# 4             1977.0                       1        0.0       1        500.0
#
#    house_area  locality  number_of_facades  number_of_rooms  open_fire  \
# 0       203.0      1050                2.0              6.0          0
# 1       250.0      1880                4.0              6.0          0
# 2       475.0      4900                4.0             11.0          0
# 3       325.0      7912                4.0              4.0          0
# 4       400.0      6032                3.0              5.0          0
#
# ...

# %% [markdown]
# Data Preparation

# %%
# from datetime import datetime
# # Converting year column to data from int
# # Handle missing or invalid years
# data['construction_year'] = pd.to_numeric(data['construction_year'], errors='coerce')  # Ensure numeric
# data = data[data['construction_year'].between(1800, datetime.now().year)]  # Filter valid years

# # Convert to datetime
# data['construction_date'] = pd.to_datetime(data['construction_year'].astype(int), format='%Y', errors='coerce')

# data = data.drop(columns=['construction_year'])

# data.head()

# %%
data.isna().sum()
# Out:
# construction_year         42738
# fully_equipped_kitchen        0
# furnished                     0
# garden                        0
# garden_area                   0
# house_area                17264
# locality                      0
# number_of_facades         27300
# number_of_rooms               4
# open_fire                     0
# price                       140
# state_of_the_building     27172
# subtype_of_property           0
# surface_of_the_land       45448
# swimming_pool                 0
# terrace                       0
# terrace_area                  0
# type_of_property              0
# type_of_sale                  0
# price_per_sqft            17352
# dtype: int64

# %%
data = data.dropna()

# %%
data.isna().sum()
# Out:
# construction_year         0
# fully_equipped_kitchen    0
# furnished                 0
# garden                    0
# garden_area               0
# house_area                0
# locality                  0
# number_of_facades         0
# number_of_rooms           0
# open_fire                 0
# price                     0
# state_of_the_building     0
# subtype_of_property       0
# surface_of_the_land       0
# swimming_pool             0
# terrace                   0
# terrace_area              0
# type_of_property          0
# type_of_sale              0
# price_per_sqft            0
# dtype: int64

# %%
data.head()
# Out:
#    construction_year  fully_equipped_kitchen  furnished  garden  garden_area  \
# 0             1901.0                       1        0.0       0          0.0
# 1             1992.0                       1        0.0       1        430.0
# 2             1853.0                       1        0.0       1       1400.0
# 3             1918.0                       1        0.0       1       2333.0
# 4             1977.0                       1        0.0       1        500.0
#
#    house_area  locality  number_of_facades  number_of_rooms  open_fire  \
# 0       203.0      1050                2.0              6.0          0
# 1       250.0      1880                4.0              6.0          0
# 2       475.0      4900                4.0             11.0          0
# 3       325.0      7912                4.0              4.0          0
# 4       400.0      6032                3.0              5.0          0
#
# ...

# %%
# Price and House feature Analysis
state_of_the_building_group = data.groupby('state_of_the_building')['price'].describe()
print(state_of_the_building_group)
subtype_of_property_group = data.groupby('subtype_of_property')['price'].describe()
print(subtype_of_property_group)
surface_of_the_land_group = data.groupby('surface_of_the_land')['price'].describe()
print(surface_of_the_land_group )
type_of_property_group = data.groupby('type_of_property')['price'].describe()
print(type_of_property_group)
type_of_sale_group = data.groupby('type_of_sale')['price'].describe()
print(type_of_sale_group)
# Out:
#                         count           mean            std      min  \
# state_of_the_building
# as new                 5506.0  429660.500182  185058.428761   2500.0
# good                   6912.0  377991.548900  183367.329997  12500.0
# just renovated         1142.0  377811.204904  172965.952608  19900.0
# to be done up          2048.0  316926.708008  165562.853642  20000.0
# to renovate            1864.0  301766.075107  175518.331643  29900.0
# to restore               84.0  293021.428571  191945.184866  75000.0
#
#                             25%       50%       75%       max
# state_of_the_building
# as new                 295000.0  378000.0  535000.0  950000.0
# good                   250000.0  339000.0  465000.0  950000.0
# just renovated         259000.0  330000.0  450000.0  950000.0
# to be done up          199000.0  279000.0  380000.0  950000.0
# to renovate            180000.0  255500.0  370750.0  950000.0
# to restore             130000.0  252500.0  440000.0  725000.0
# ...

# %%
# Price Per sqft and House feature Analysis
state_of_the_building_group = data.groupby('state_of_the_building')['price_per_sqft'].describe()
print(state_of_the_building_group)
subtype_of_property_group = data.groupby('subtype_of_property')['price_per_sqft'].describe()
print(subtype_of_property_group)
surface_of_the_land_group = data.groupby('surface_of_the_land')['price_per_sqft'].describe()
print(surface_of_the_land_group )
type_of_property_group = data.groupby('type_of_property')['price_per_sqft'].describe()
print(type_of_property_group)
type_of_sale_group = data.groupby('type_of_sale')['price_per_sqft'].describe()
print(type_of_sale_group)
# Out:
#                         count         mean          std         min  \
# state_of_the_building
# as new                 5506.0  2226.001806  5850.292225    4.166667
# good                   6912.0  1872.407527   775.350521   73.529412
# just renovated         1142.0  2009.688037   672.956946  330.882353
# to be done up          2048.0  1700.108497   734.661775  173.913043
# to renovate            1864.0  1586.946265   774.617575  172.500000
# to restore               84.0  1398.752153  1110.566406  214.285714
#
#                                25%          50%          75%            max
# state_of_the_building
# as new                 1668.141593  2055.151515  2458.333333  307000.000000
# good                   1384.373488  1782.053571  2240.816327   20238.095238
# just renovated         1510.602679  1939.597315  2391.381988    5500.000000
# to be done up          1180.000000  1567.231638  2089.182969    7941.176471
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 17556 entries, 0 to 104103
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   construction_year       17556 non-null  float64
#  1   fully_equipped_kitchen  17556 non-null  int64
#  2   furnished               17556 non-null  float64
#  3   garden                  17556 non-null  int64
#  4   garden_area             17556 non-null  float64
#  5   house_area              17556 non-null  float64
#  6   locality                17556 non-null  int64
#  7   number_of_facades       17556 non-null  float64
#  8   number_of_rooms         17556 non-null  float64
#  9   open_fire               17556 non-null  int64
#  10  price                   17556 non-null  float64
#  11  state_of_the_building   17556 non-null  object
#  12  subtype_of_property     17556 non-null  object
#  13  surface_of_the_land     17556 non-null  float64
# ...

# %% [markdown]
# Visualization

# %%
# Import necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# 1. Distribution of Price
plt.figure(figsize=(10, 6))
sns.histplot(data['price'], bins=30, kde=True, color='blue')
plt.title('Distribution of Prices')
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.show()

# %%
# 2. Boxplot: Price by Type of Property
plt.figure(figsize=(10, 6))
sns.boxplot(x='type_of_property', y='price', data=data)
plt.title('Price Distribution by Type of Property')
plt.xlabel('Type of Property')
plt.ylabel('Price')
plt.show()

# %%
# 3. Countplot: Distribution of State of Building
plt.figure(figsize=(10, 6))
sns.countplot(x='state_of_the_building', data=data, palette='Set2')
plt.title('Count of Properties by State of the Building')
plt.xlabel('State of the Building')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\shiro\AppData\Local\Temp\ipykernel_5328\1134190740.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='state_of_the_building', data=data, palette='Set2')

# %%
# 4. Scatterplot: Price vs. House Area
plt.figure(figsize=(10, 6))
sns.scatterplot(x='house_area', y='price', hue='type_of_property', data=data)
plt.title('Price vs. House Area by Property Type')
plt.xlabel('House Area')
plt.ylabel('Price')
plt.legend(title='Property Type')
plt.show()

# %%
# 5. Pairplot: Correlation Between Numerical Columns
sns.pairplot(data[['price', 'house_area', 'garden_area', 'price_per_sqft', 'number_of_rooms']], diag_kind='kde')
plt.show()

# %%
# 6. Heatmap: Correlation Matrix
plt.figure(figsize=(10, 6))
correlation_matrix = data.corr(numeric_only=True)
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Heatmap')
plt.show()

# %%
# 7. Boxplot: Price per State of the Building
plt.figure(figsize=(10, 6))
sns.boxplot(x='state_of_the_building', y='price', data=data)
plt.title('Price by State of the Building')
plt.xlabel('State of the Building')
plt.ylabel('Price')
plt.xticks(rotation=45)
plt.show()

# %%
# 8. Barplot: Average Price by Number of Facades
plt.figure(figsize=(10, 6))
sns.barplot(x='number_of_facades', y='price', data=data, ci=None, palette='muted')
plt.title('Average Price by Number of Facades')
plt.xlabel('Number of Facades')
plt.ylabel('Average Price')
plt.show()
# Out:
# C:\Users\shiro\AppData\Local\Temp\ipykernel_5328\3222592627.py:3: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='number_of_facades', y='price', data=data, ci=None, palette='muted')
# C:\Users\shiro\AppData\Local\Temp\ipykernel_5328\3222592627.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='number_of_facades', y='price', data=data, ci=None, palette='muted')

# %%
# 9. Boxplot: Price per Number of Rooms
plt.figure(figsize=(10, 6))
sns.boxplot(x='number_of_rooms', y='price', data=data)
plt.title('Price by Number of Rooms')
plt.xlabel('Number of Rooms')
plt.ylabel('Price')
plt.show()

# %%
# 10. Countplot: Properties with Swimming Pool
plt.figure(figsize=(10, 6))
sns.countplot(x='swimming_pool', data=data, palette='cool')
plt.title('Count of Properties with and without Swimming Pool')
plt.xlabel('Swimming Pool (1 = Yes, 0 = No)')
plt.ylabel('Count')
plt.show()
# Out:
# C:\Users\shiro\AppData\Local\Temp\ipykernel_5328\2753703425.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='swimming_pool', data=data, palette='cool')

# %%
# 11. Boxplot: Price per Fully Equipped Kitchen
plt.figure(figsize=(10, 6))
sns.boxplot(x='fully_equipped_kitchen', y='price', data=data)
plt.title('Price by Fully Equipped Kitchen')
plt.xlabel('Fully Equipped Kitchen (1 = Yes, 0 = No)')
plt.ylabel('Price')
plt.show()

# %%
# 12. Barplot: Average Price per Locality
plt.figure(figsize=(12, 6))
sns.barplot(x='locality', y='price', data=data, ci=None)
plt.title('Average Price by Locality')
plt.xlabel('Locality')
plt.ylabel('Average Price')
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\shiro\AppData\Local\Temp\ipykernel_5328\3659621612.py:3: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='locality', y='price', data=data, ci=None)

# %%
# 13. Scatterplot: Price vs Garden Area
plt.figure(figsize=(10, 6))
sns.scatterplot(x='garden_area', y='price', hue='type_of_property', data=data)
plt.title('Price vs. Garden Area by Property Type')
plt.xlabel('Garden Area')
plt.ylabel('Price')
plt.legend(title='Property Type')
plt.show()

# %%
# 14. Barplot: Average Price per Sale Type
plt.figure(figsize=(10, 6))
sns.barplot(x='type_of_sale', y='price', data=data, ci=None, palette='Set3')
plt.title('Average Price by Type of Sale')
plt.xlabel('Type of Sale')
plt.ylabel('Average Price')
plt.show()
# Out:
# C:\Users\shiro\AppData\Local\Temp\ipykernel_5328\21381575.py:3: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='type_of_sale', y='price', data=data, ci=None, palette='Set3')
# C:\Users\shiro\AppData\Local\Temp\ipykernel_5328\21381575.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='type_of_sale', y='price', data=data, ci=None, palette='Set3')

# %%
# 15. Violinplot: Price Distribution by Type of Property
plt.figure(figsize=(10, 6))
sns.violinplot(x='type_of_property', y='price', data=data, palette='muted', split=True)
plt.title('Price Distribution by Type of Property')
plt.xlabel('Type of Property')
plt.ylabel('Price')
plt.show()
# Out:
# C:\Users\shiro\AppData\Local\Temp\ipykernel_5328\846465774.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x='type_of_property', y='price', data=data, palette='muted', split=True)

# %%
# 16. Stripplot: Number of Rooms vs Price
plt.figure(figsize=(10, 6))
sns.stripplot(x='number_of_rooms', y='price', data=data, jitter=True, hue='type_of_sale', palette='cool', dodge=True)
plt.title('Price by Number of Rooms and Sale Type')
plt.xlabel('Number of Rooms')
plt.ylabel('Price')
plt.legend(title='Type of Sale')
plt.show()

# %%
# 17. Heatmap: Count of Properties by Type of Property and State of the Building
plt.figure(figsize=(10, 6))
cross_tab = pd.crosstab(data['type_of_property'], data['state_of_the_building'])
sns.heatmap(cross_tab, annot=True, fmt="d", cmap="YlGnBu")
plt.title('Count of Properties by Property Type and State of the Building')
plt.xlabel('State of the Building')
plt.ylabel('Type of Property')
plt.show()

# %%
# 18. Barplot: Average Price vs Terrace Area
plt.figure(figsize=(10, 6))
sns.barplot(x='terrace', y='price', data=data, ci=None, hue='terrace_area', palette='viridis')
plt.title('Price vs Terrace Presence and Area')
plt.xlabel('Terrace (1 = Yes, 0 = No)')
plt.ylabel('Average Price')
plt.legend(title='Terrace Area')
plt.show()
# Out:
# C:\Users\shiro\AppData\Local\Temp\ipykernel_5328\1427611213.py:3: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='terrace', y='price', data=data, ci=None, hue='terrace_area', palette='viridis')

# %%
# 19. Jointplot: House Area vs Price with KDE
sns.jointplot(x='house_area', y='price', data=data, kind='kde', fill=True, cmap='Reds')
plt.suptitle('Joint Distribution of House Area and Price', y=1.02)
plt.show()

# %%
# 20. Countplot: Distribution of Terrace Area (Binned)
data['terrace_area_binned'] = pd.cut(data['terrace_area'], bins=[0, 20, 50, 100, 200, 500], labels=['0-20', '21-50', '51-100', '101-200', '>200'])
plt.figure(figsize=(10, 6))
sns.countplot(x='terrace_area_binned', data=data, palette='coolwarm')
plt.title('Count of Properties by Terrace Area (Binned)')
plt.xlabel('Terrace Area Range (sqft)')
plt.ylabel('Count')
plt.show()
# Out:
# C:\Users\shiro\AppData\Local\Temp\ipykernel_5328\1916327607.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='terrace_area_binned', data=data, palette='coolwarm')

# %%
# 21. Histogram: Distribution of Number of Facades
plt.figure(figsize=(10, 6))
sns.histplot(data['number_of_facades'], bins=8, kde=True, color='purple')
plt.title('Distribution of Number of Facades')
plt.xlabel('Number of Facades')
plt.ylabel('Frequency')
plt.show()

# %%
# 22. Boxenplot: Garden Area vs Price
plt.figure(figsize=(10, 6))
sns.boxenplot(x='garden', y='price', data=data, palette='Set3')
plt.title('Price Distribution by Garden Presence')
plt.xlabel('Garden (1 = Yes, 0 = No)')
plt.ylabel('Price')
plt.show()
# Out:
# C:\Users\shiro\AppData\Local\Temp\ipykernel_5328\4062993379.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxenplot(x='garden', y='price', data=data, palette='Set3')

# %%
# 23. Lineplot: Price Per Square Foot Over Construction Years
data['construction_year'] = data['construction_year'].astype(int)  # Ensure year is an integer
avg_price_per_sqft = data.groupby('construction_year')['price_per_sqft'].mean().reset_index()
plt.figure(figsize=(12, 6))
sns.lineplot(x='construction_year', y='price_per_sqft', data=avg_price_per_sqft, marker='o', color='orange')
plt.title('Average Price Per Square Foot Over Years')
plt.xlabel('Construction Year')
plt.ylabel('Price Per Square Foot')
plt.show()

# %%
# 24. Boxplot: Price vs Swimming Pool Presence
plt.figure(figsize=(10, 6))
sns.boxplot(x='swimming_pool', y='price', data=data, palette='Blues')
plt.title('Price Distribution by Swimming Pool Presence')
plt.xlabel('Swimming Pool (1 = Yes, 0 = No)')
plt.ylabel('Price')
plt.show()
# Out:
# C:\Users\shiro\AppData\Local\Temp\ipykernel_5328\3163908800.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='swimming_pool', y='price', data=data, palette='Blues')

# %%
# 25. Countplot: Fully Equipped Kitchen Distribution
plt.figure(figsize=(10, 6))
sns.countplot(x='fully_equipped_kitchen', data=data, palette='Oranges')
plt.title('Count of Properties with Fully Equipped Kitchen')
plt.xlabel('Fully Equipped Kitchen (1 = Yes, 0 = No)')
plt.ylabel('Count')
plt.show()
# Out:
# C:\Users\shiro\AppData\Local\Temp\ipykernel_5328\3865672363.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='fully_equipped_kitchen', data=data, palette='Oranges')

# %%
# 26. Lineplot: Price Over Number of Rooms
avg_price_by_rooms = data.groupby('number_of_rooms')['price'].mean().reset_index()
plt.figure(figsize=(12, 6))
sns.lineplot(x='number_of_rooms', y='price', data=avg_price_by_rooms, marker='o', color='green')
plt.title('Average Price by Number of Rooms')
plt.xlabel('Number of Rooms')
plt.ylabel('Average Price')
plt.show()

# %%
# 27. Pairplot: Compare Key Categorical Relationships
sns.pairplot(data, hue='type_of_property', diag_kind='hist', vars=['price', 'house_area', 'garden_area', 'price_per_sqft'])
plt.suptitle('Pairwise Analysis of Key Features', y=1.02)
plt.show()

# %%
# 28. Catplot: Price by Subtype of Property and Sale Type
sns.catplot(
    x="subtype_of_property", 
    y="price", 
    hue="type_of_sale", 
    kind="bar", 
    data=data, 
    height=6, 
    aspect=2, 
    palette="husl"
)
plt.title('Price by Subtype of Property and Sale Type')
plt.xlabel('Subtype of Property')
plt.ylabel('Price')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Statistical analysis

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import pearsonr, spearmanr, chi2_contingency, normaltest, ttest_ind, f_oneway
from sklearn.feature_selection import mutual_info_classif, SelectKBest

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Define the numerical columns in your data
numerical_columns = data.select_dtypes(include=["float64", "int64"]).columns

# Adjust the number of rows and columns for the subplot grid based on the number of numerical columns
num_plots = len(numerical_columns)
num_cols = 3  # You can adjust this to any number that fits your preference
num_rows = (num_plots // num_cols) + (num_plots % num_cols > 0)  # Calculate the required number of rows

# Create the histograms for all numerical columns
plt.figure(figsize=(num_cols * 6, num_rows * 4))  # Dynamically set figure size
for i, col in enumerate(numerical_columns):
    plt.subplot(num_rows, num_cols, i + 1)
    sns.histplot(data[col], kde=True, bins=30, color='blue')  # KDE helps show the distribution shape
    plt.title(f'Distribution of {col}')
plt.tight_layout()
plt.show()

# Boxplots for outliers
plt.figure(figsize=(num_cols * 6, num_rows * 4))  # Adjust the figure size based on layout
for i, col in enumerate(numerical_columns):
    plt.subplot(num_rows, num_cols, i + 1)
    sns.boxplot(data=data, x=col)
    plt.title(f"Boxplot for {col}")
plt.tight_layout()
plt.show()

# KDE plots for the distribution of each feature
for col in numerical_columns:
    sns.kdeplot(data=data, x=col, fill=True)
    plt.title(f"Distribution for {col}")
    plt.show()
# Out:
# C:\Users\shiro\AppData\Local\Temp\ipykernel_5328\3605098341.py:32: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(data=data, x=col, fill=True)

# %%
categorical_columns = data.select_dtypes(include=["object"]).columns

plt.figure(figsize=(20, 10))
for i, col in enumerate(categorical_columns):
    plt.subplot(2, 2, i+1)
    sns.countplot(data=data, x=col)
    plt.title(f"Bar Plot for {col}")
    plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
X = data[numerical_columns].drop("price", axis=1, errors="ignore")
y = data["price"]

mi = mutual_info_classif(X, y, discrete_features=False)
mi_scores = pd.Series(mi, index=X.columns)
mi_scores = mi_scores.sort_values(ascending=False)

plt.figure(figsize=(10, 5))
sns.barplot(x=mi_scores.values, y=mi_scores.index)
plt.title("Mutual Information Scores for Numerical Features")
plt.show()
# Out:
# c:\SIDDHANT\Projects\Real_Estate_Analysis\venv\lib\site-packages\joblib\externals\loky\backend\context.py:136: UserWarning: Could not find the number of physical cores for the following reason:
# [WinError 2] The system cannot find the file specified
# Returning the number of logical cores instead. You can silence this warning by setting LOKY_MAX_CPU_COUNT to the number of cores you want to use.
#   warnings.warn(
#   File "c:\SIDDHANT\Projects\Real_Estate_Analysis\venv\lib\site-packages\joblib\externals\loky\backend\context.py", line 257, in _count_physical_cores
#     cpu_info = subprocess.run(
#   File "c:\SIDDHANT\Projects\Real_Estate_Analysis\venv\lib\subprocess.py", line 501, in run
#     with Popen(*popenargs, **kwargs) as process:
#   File "c:\SIDDHANT\Projects\Real_Estate_Analysis\venv\lib\subprocess.py", line 966, in __init__
#     self._execute_child(args, executable, preexec_fn, close_fds,
# ...

# %%
for col in categorical_columns:
    contingency_table = pd.crosstab(data[col], data["type_of_property"])
    chi2, p, dof, expected = chi2_contingency(contingency_table)
    print(f"Chi-Square Test for {col} vs. type_of_property:")
    print(f"Chi2: {chi2:.2f}, p-value: {p:.4f}\n")
# Out:
# Chi-Square Test for state_of_the_building vs. type_of_property:
# Chi2: 0.00, p-value: 1.0000
#
# Chi-Square Test for subtype_of_property vs. type_of_property:
# Chi2: 0.00, p-value: 1.0000
#
# Chi-Square Test for type_of_property vs. type_of_property:
# Chi2: 0.00, p-value: 1.0000
#
# Chi-Square Test for type_of_sale vs. type_of_property:
# Chi2: 0.00, p-value: 1.0000

# %%
for col in numerical_columns:
    stat, p = normaltest(data[col])
    print(f"Normality Test for {col}: Stat={stat:.2f}, p-value={p:.4f}")
    if p < 0.05:
        print(f"  {col} is not normally distributed.\n")
    else:
        print(f"  {col} is normally distributed.\n")
# Out:
# Normality Test for construction_year: Stat=3056.89, p-value=0.0000
#   construction_year is not normally distributed.
#
# Normality Test for fully_equipped_kitchen: Stat=3584.91, p-value=0.0000
#   fully_equipped_kitchen is not normally distributed.
#
# Normality Test for furnished: Stat=nan, p-value=nan
#   furnished is normally distributed.
#
# Normality Test for garden: Stat=60998.45, p-value=0.0000
#   garden is not normally distributed.
#
# Normality Test for garden_area: Stat=44035.06, p-value=0.0000
#   garden_area is not normally distributed.
#
# Normality Test for house_area: Stat=20030.07, p-value=0.0000
#   house_area is not normally distributed.
#
# Normality Test for locality: Stat=84173.66, p-value=0.0000
#   locality is not normally distributed.
#
# Normality Test for number_of_facades: Stat=120664.49, p-value=0.0000
#   number_of_facades is not normally distributed.
#
# Normality Test for number_of_rooms: Stat=6792.01, p-value=0.0000
# ...

# %%
# import scipy.stats as stats

# # Check the number of unique categories in the 'type_of_property'
# unique_types = data["type_of_property"].nunique()

# # If there are more than two unique property types, perform ANOVA, else T-test
# if unique_types > 2:
#     groups = data.groupby("type_of_property")["price"].apply(list)
#     stat, p = stats.f_oneway(*groups)
#     print(f"ANOVA Test: Stat={stat:.2f}, p-value={p:.4f}")
# elif unique_types == 2:
#     groups = data.groupby("type_of_property")["price"].apply(list)
#     stat, p = stats.ttest_ind(*groups)
#     print(f"T-Test: Stat={stat:.2f}, p-value={p:.4f}")
# else:
#     print("Insufficient data for comparison (only one property type).")

# %%
from sklearn.ensemble import RandomForestRegressor

# Feature importance using Random Forest
model = RandomForestRegressor()
model.fit(X, y)

feature_importances = pd.Series(model.feature_importances_, index=X.columns)
feature_importances = feature_importances.sort_values(ascending=False)

plt.figure(figsize=(10, 5))
sns.barplot(x=feature_importances.values, y=feature_importances.index)
plt.title("Feature Importances using Random Forest")
plt.show()

# %%
from scipy.stats import zscore

z_scores = np.abs(zscore(data[numerical_columns]))
outliers = (z_scores > 3).any(axis=1)
print(f"Number of outliers: {outliers.sum()}")
# Out:
# Number of outliers: 1572

# %%
target_corr = data[numerical_columns].corrwith(data["price"])
target_corr = target_corr.sort_values(ascending=False)

plt.figure(figsize=(10, 5))
sns.barplot(x=target_corr.values, y=target_corr.index)
plt.title("Correlation with Target Variable (Price)")
plt.show()
# Out:
# c:\SIDDHANT\Projects\Real_Estate_Analysis\venv\lib\site-packages\numpy\lib\_function_base_impl.py:3045: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# c:\SIDDHANT\Projects\Real_Estate_Analysis\venv\lib\site-packages\numpy\lib\_function_base_impl.py:3046: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]

# %% [markdown]
# ### FINAL SUMMARY
